# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("C:/Users/sneha/Downloads/FAOSTAT_data_en_1-7-2024.csv")

# %%
df
# Out:
#       Domain Code            Domain  Area Code (M49)         Area  \
# 0              MK  Macro Indicators                4  Afghanistan
# 1              MK  Macro Indicators                4  Afghanistan
# 2              MK  Macro Indicators                4  Afghanistan
# 3              MK  Macro Indicators                4  Afghanistan
# 4              MK  Macro Indicators                4  Afghanistan
# ...           ...               ...              ...          ...
# 10690          MK  Macro Indicators              716     Zimbabwe
# 10691          MK  Macro Indicators              716     Zimbabwe
# 10692          MK  Macro Indicators              716     Zimbabwe
# 10693          MK  Macro Indicators              716     Zimbabwe
# 10694          MK  Macro Indicators              716     Zimbabwe
#
#        Element Code    Element  Item Code                    Item  Year Code  \
# 0              6110  Value US$      22008  Gross Domestic Product       1970
# ...

# %%
df1 = pd.read_csv("C:\\Users\\sneha\\Downloads\\P_Data_Extract_From_World_Development_Indicators\\ca52db21-6e0b-4ff9-9613-4b8fa3b3c078_Series - Metadata.csv", encoding = 'latin1')

# %%
df1
# Out:
#                                           Series Name   Series Code  \
# 0                                          Gini index   SI.POV.GINI
# 1                                          Gini index   SI.POV.GINI
# 2                                          Gini index   SI.POV.GINI
# 3                                          Gini index   SI.POV.GINI
# 4                                          Gini index   SI.POV.GINI
# ..                                                ...           ...
# 268                                               NaN           NaN
# 269  Data from database: World Development Indicators           NaN
# 270                          Last Updated: 12/18/2023           NaN
# 271                                              Code  License Type
# 272                                       SI.POV.GINI     CC BY-4.0
#
#        Country Name                                       Country Code  \
# 0       Afghanistan                                                AFG
# ...

# %%
df2 = pd.read_csv("C:\\Users\\sneha\\Downloads\\P_Data_Extract_From_World_Development_Indicators\\ca52db21-6e0b-4ff9-9613-4b8fa3b3c078_Data.csv", encoding = 'latin1')

# %%
df2
# Out:
#                                           Series Name  Series Code  \
# 0                                          Gini index  SI.POV.GINI
# 1                                          Gini index  SI.POV.GINI
# 2                                          Gini index  SI.POV.GINI
# 3                                          Gini index  SI.POV.GINI
# 4                                          Gini index  SI.POV.GINI
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 12/18/2023          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2013 [YR2013]  \
# 0       Afghanistan          AFG            ..            ..            ..
# ...

# %%
df2['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
df3 = pd.read_csv("C:/Users/sneha/Downloads/FAOSTAT_data_en_1-7-2024 (1).csv")
df3
# Out:
#       Domain Code            Domain  Area Code (M49)         Area  \
# 0              MK  Macro Indicators                4  Afghanistan
# 1              MK  Macro Indicators                4  Afghanistan
# 2              MK  Macro Indicators                4  Afghanistan
# 3              MK  Macro Indicators                4  Afghanistan
# 4              MK  Macro Indicators                4  Afghanistan
# ...           ...               ...              ...          ...
# 10652          MK  Macro Indicators              716     Zimbabwe
# 10653          MK  Macro Indicators              716     Zimbabwe
# 10654          MK  Macro Indicators              716     Zimbabwe
# 10655          MK  Macro Indicators              716     Zimbabwe
# 10656          MK  Macro Indicators              716     Zimbabwe
#
#        Element Code               Element  Item Code                    Item  \
# 0              6119  Value US$ per capita      22008  Gross Domestic Product
# ...

# %%
gdp = df

# %%
gdp
# Out:
#       Domain Code            Domain  Area Code (M49)         Area  \
# 0              MK  Macro Indicators                4  Afghanistan
# 1              MK  Macro Indicators                4  Afghanistan
# 2              MK  Macro Indicators                4  Afghanistan
# 3              MK  Macro Indicators                4  Afghanistan
# 4              MK  Macro Indicators                4  Afghanistan
# ...           ...               ...              ...          ...
# 10690          MK  Macro Indicators              716     Zimbabwe
# 10691          MK  Macro Indicators              716     Zimbabwe
# 10692          MK  Macro Indicators              716     Zimbabwe
# 10693          MK  Macro Indicators              716     Zimbabwe
# 10694          MK  Macro Indicators              716     Zimbabwe
#
#        Element Code    Element  Item Code                    Item  Year Code  \
# 0              6110  Value US$      22008  Gross Domestic Product       1970
# ...

# %%
gdp_col_keep = ['Area', 'Item', 'Year', 'Value', 'Unit']

gdp = gdp[gdp_col_keep]

gdp
# Out:
#               Area                    Item  Year         Value         Unit
# 0      Afghanistan  Gross Domestic Product  1970   1731.435587  million USD
# 1      Afghanistan  Gross Domestic Product  1971   1812.837521  million USD
# 2      Afghanistan  Gross Domestic Product  1972   1647.900178  million USD
# 3      Afghanistan  Gross Domestic Product  1973   1702.716294  million USD
# 4      Afghanistan  Gross Domestic Product  1974   2061.729287  million USD
# ...            ...                     ...   ...           ...          ...
# 10690     Zimbabwe  Gross Domestic Product  2018  23645.265549  million USD
# 10691     Zimbabwe  Gross Domestic Product  2019  22594.520375  million USD
# 10692     Zimbabwe  Gross Domestic Product  2020  21664.745864  million USD
# 10693     Zimbabwe  Gross Domestic Product  2021  24118.150864  million USD
# 10694     Zimbabwe  Gross Domestic Product  2022  25354.615234  million USD
#
# [10695 rows x 5 columns]

# %%
gini = df2

gini
# Out:
#                                           Series Name  Series Code  \
# 0                                          Gini index  SI.POV.GINI
# 1                                          Gini index  SI.POV.GINI
# 2                                          Gini index  SI.POV.GINI
# 3                                          Gini index  SI.POV.GINI
# 4                                          Gini index  SI.POV.GINI
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 12/18/2023          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2013 [YR2013]  \
# 0       Afghanistan          AFG            ..            ..            ..
# ...

# %%
column_name = "Country Name"
Val_exclude = ['Africa Eastern and Southern', 'Africa Western and Central',
       'Arab World', 'Caribbean small states',
       'Central Europe and the Baltics', 'Early-demographic dividend',
       'East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
       'Fragile and conflict affected situations',
       'Heavily indebted poor countries (HIPC)', 'High income',
       'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
       'IDA total', 'Late-demographic dividend',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Latin America & the Caribbean (IDA & IBRD countries)',
       'Least developed countries: UN classification',
       'Low & middle income', 'Low income', 'Lower middle income',
       'Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Middle East & North Africa (IDA & IBRD countries)',
       'Middle income', 'North America', 'Not classified', 'OECD members',
       'Other small states', 'Pacific island small states',
       'Post-demographic dividend', 'Pre-demographic dividend',
       'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
       'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
       'World', 'nan']

gini = gini[~gini[column_name].isin(Val_exclude)]

gini
# Out:
#                                           Series Name  Series Code  \
# 0                                          Gini index  SI.POV.GINI
# 1                                          Gini index  SI.POV.GINI
# 2                                          Gini index  SI.POV.GINI
# 3                                          Gini index  SI.POV.GINI
# 4                                          Gini index  SI.POV.GINI
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 12/18/2023          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2013 [YR2013]  \
# 0       Afghanistan          AFG            ..            ..            ..
# ...

# %%
gini['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
# ...

# %%
melted_df = pd.melt(gini, id_vars=['Country Name', "Country Code"], var_name='Year', value_name='Value')

# Convert the 'time' column to int
melted_df['Year'] = melted_df['Year']

melted_df
# Out:
#         Country Name Country Code           Year       Value
# 0        Afghanistan          AFG    Series Name  Gini index
# 1            Albania          ALB    Series Name  Gini index
# 2            Algeria          DZA    Series Name  Gini index
# 3     American Samoa          ASM    Series Name  Gini index
# 4            Andorra          AND    Series Name  Gini index
# ...              ...          ...            ...         ...
# 3103             NaN          NaN  2022 [YR2022]         NaN
# 3104             NaN          NaN  2022 [YR2022]         NaN
# 3105             NaN          NaN  2022 [YR2022]         NaN
# 3106             NaN          NaN  2022 [YR2022]         NaN
# 3107             NaN          NaN  2022 [YR2022]         NaN
#
# [3108 rows x 4 columns]

# %%
melted_df['Year'].unique()
# Out:
# array(['Series Name', 'Series Code', '1990 [YR1990]', '2000 [YR2000]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]',
#        '2021 [YR2021]', '2022 [YR2022]'], dtype=object)

# %%
column_name = "Year"
Val_exclude = ['Series Name', 'Series Code']

melted_df = melted_df[~melted_df[column_name].isin(Val_exclude)]

melted_df
# Out:
#         Country Name Country Code           Year Value
# 444      Afghanistan          AFG  1990 [YR1990]    ..
# 445          Albania          ALB  1990 [YR1990]    ..
# 446          Algeria          DZA  1990 [YR1990]    ..
# 447   American Samoa          ASM  1990 [YR1990]    ..
# 448          Andorra          AND  1990 [YR1990]    ..
# ...              ...          ...            ...   ...
# 3103             NaN          NaN  2022 [YR2022]   NaN
# 3104             NaN          NaN  2022 [YR2022]   NaN
# 3105             NaN          NaN  2022 [YR2022]   NaN
# 3106             NaN          NaN  2022 [YR2022]   NaN
# 3107             NaN          NaN  2022 [YR2022]   NaN
#
# [2664 rows x 4 columns]

# %%
gini_coeff = melted_df

# %%
df3
# Out:
#       Domain Code            Domain  Area Code (M49)         Area  \
# 0              MK  Macro Indicators                4  Afghanistan
# 1              MK  Macro Indicators                4  Afghanistan
# 2              MK  Macro Indicators                4  Afghanistan
# 3              MK  Macro Indicators                4  Afghanistan
# 4              MK  Macro Indicators                4  Afghanistan
# ...           ...               ...              ...          ...
# 10652          MK  Macro Indicators              716     Zimbabwe
# 10653          MK  Macro Indicators              716     Zimbabwe
# 10654          MK  Macro Indicators              716     Zimbabwe
# 10655          MK  Macro Indicators              716     Zimbabwe
# 10656          MK  Macro Indicators              716     Zimbabwe
#
#        Element Code               Element  Item Code                    Item  \
# 0              6119  Value US$ per capita      22008  Gross Domestic Product
# ...

# %%
gdp_per_capita = df3

# %%
gdp_per_capita_col_keep = ['Area', 'Item', 'Year', 'Value', 'Unit']

gdp_per_capita = gdp_per_capita[gdp_per_capita_col_keep]

gdp_per_capita
# Out:
#               Area                    Item  Year        Value Unit
# 0      Afghanistan  Gross Domestic Product  1970   161.019274  USD
# 1      Afghanistan  Gross Domestic Product  1971   164.566181  USD
# 2      Afghanistan  Gross Domestic Product  1972   146.003034  USD
# 3      Afghanistan  Gross Domestic Product  1973   147.099044  USD
# 4      Afghanistan  Gross Domestic Product  1974   173.694213  USD
# ...            ...                     ...   ...          ...  ...
# 10652     Zimbabwe  Gross Domestic Product  2018  1570.886029  USD
# 10653     Zimbabwe  Gross Domestic Product  2019  1471.513983  USD
# 10654     Zimbabwe  Gross Domestic Product  2020  1382.591426  USD
# 10655     Zimbabwe  Gross Domestic Product  2021  1507.994790  USD
# 10656     Zimbabwe  Gross Domestic Product  2022  1553.540501  USD
#
# [10657 rows x 5 columns]

# %%
gini_coeff.to_csv('C:\\Users\\sneha\\Downloads\\gini_coeff.csv', index=False)

# %%
gdp.to_csv('C:\\Users\\sneha\\Downloads\\gdp.csv', index = False)

# %%
gdp_per_capita.to_csv('C:\\Users\\sneha\\Downloads\\gdp_per_capita.csv', index=False)
